# %%
# !unzip -q '/content/GloVe-1.2.zip' -d '/content/glove/'
# Out:
# replace /content/glove/GloVe-1.2/.gitignore? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
game_file = 'steam_app_data.csv'

# %%
import pandas as pd
import numpy as np

# %%
import torch

# %%
game_csv = pd.read_csv(game_file)

# %%
game_csv
# Out:
#      type                       name  steam_appid  required_age is_free  \
# 0    game             Counter-Strike           10           0.0   False
# 1    game      Team Fortress Classic           20           0.0   False
# 2    game              Day of Defeat           30           0.0   False
# 3    game         Deathmatch Classic           40           0.0   False
# 4    game  Half-Life: Opposing Force           50           0.0   False
# ..    ...                        ...          ...           ...     ...
# 995  game                    Brotato      1942280           0.0   False
# 996  game       Escape the Backrooms      1943950           0.0   False
# 997  game                Broken Edge      1947070           0.0   False
# 998  game       Inside the Backrooms      1987080           0.0   False
# 999  game            Resident Evil 4      2050650          18.0   False
#
#     controller_support                                                dlc  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ..                 ...                                                ...
# 995               full                                                NaN
# 996                NaN                                                NaN
# 997                NaN                                                NaN
# 998                NaN                                                NaN
# 999               full  [2109315, 2109301, 2109303, 2109304, 2109305, ...
#
#                                   detailed_description  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  <h1>Previous games</h1><p><a href="https://sto...
# 996  Explore the seemingly infinite expanse of eeri...
# 997  <img src="https://cdn.akamai.steamstatic.com/s...
# 998  <img src="https://cdn.akamai.steamstatic.com/s...
# 999  <h1>Digital Deluxe Edition</h1><p><img src="ht...
#
#                                         about_the_game  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  A spaceship from Potato World crashes onto an ...
# 996  Explore the seemingly infinite expanse of eeri...
# 997  <img src="https://cdn.akamai.steamstatic.com/s...
# 998  <img src="https://cdn.akamai.steamstatic.com/s...
# 999  Survival is just the beginning.<br />\r\n<br /...
#
#                                      short_description  ...  \
# 0    Play the world's number 1 online action game. ...  ...
# 1    One of the most popular online action games of...  ...
# 2    Enlist in an intense brand of Axis vs. Allied ...  ...
# 3    Enjoy fast-paced multiplayer gaming with Death...  ...
# 4    Return to the Black Mesa Research Facility as ...  ...
# ..                                                 ...  ...
# 995  Brotato is a top-down arena shooter roguelite ...  ...
# 996  Escape the Backrooms is a 1-4 player co-op hor...  ...
# 997  Broken Edge is a VR multiplayer fantasy duelin...  ...
# 998  Inside the Backrooms is a horror multiplayer g...  ...
# 999  Survival is just the beginning. Six years have...  ...
#
#                                             categories  \
# 0    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4    [{'id': 2, 'description': 'Single-player'}, {'...
# ..                                                 ...
# 995  [{'id': 2, 'description': 'Single-player'}, {'...
# 996  [{'id': 2, 'description': 'Single-player'}, {'...
# 997  [{'id': 2, 'description': 'Single-player'}, {'...
# 998  [{'id': 2, 'description': 'Single-player'}, {'...
# 999  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                 genres  \
# 0               [{'id': '1', 'description': 'Action'}]
# 1               [{'id': '1', 'description': 'Action'}]
# 2               [{'id': '1', 'description': 'Action'}]
# 3               [{'id': '1', 'description': 'Action'}]
# 4               [{'id': '1', 'description': 'Action'}]
# ..                                                 ...
# 995  [{'id': '1', 'description': 'Action'}, {'id': ...
# 996  [{'id': '23', 'description': 'Indie'}, {'id': ...
# 997             [{'id': '1', 'description': 'Action'}]
# 998  [{'id': '25', 'description': 'Adventure'}, {'i...
# 999  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                            screenshots  \
# 0    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 1    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 2    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 3    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ..                                                 ...
# 995  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 996  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 997  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 998  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 999  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                 movies    recommendations  \
# 0                                                  NaN  {'total': 137378}
# 1                                                  NaN    {'total': 5474}
# 2                                                  NaN    {'total': 3694}
# 3                                                  NaN    {'total': 1924}
# 4                                                  NaN   {'total': 15478}
# ..                                                 ...                ...
# 995  [{'id': 256954513, 'name': 'Full Release Trail...   {'total': 42508}
# 996  [{'id': 256899680, 'name': 'Early Access', 'th...   {'total': 26628}
# 997  [{'id': 256916792, 'name': 'Launch Trailer [ST...     {'total': 239}
# 998  [{'id': 256894396, 'name': 'Official Trailer',...   {'total': 29745}
# 999  [{'id': 256938323, 'name': '06【RE4】_PV3_Multi_...   {'total': 53998}
#
#                                           achievements  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  {'total': 83, 'highlighted': [{'name': 'Surviv...
# 996  {'total': 25, 'highlighted': [{'name': 'Escape...
# 997                                                NaN
# 998  {'total': 20, 'highlighted': [{'name': 'INSIDE...
# 999  {'total': 46, 'highlighted': [{'name': 'Knife ...
#
#                                        release_date  \
# 0     {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1     {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2     {'coming_soon': False, 'date': '1 May, 2003'}
# 3     {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4     {'coming_soon': False, 'date': '1 Nov, 1999'}
# ..                                              ...
# 995  {'coming_soon': False, 'date': '23 Jun, 2023'}
# 996  {'coming_soon': False, 'date': '11 Aug, 2022'}
# 997  {'coming_soon': False, 'date': '17 Nov, 2022'}
# 998  {'coming_soon': False, 'date': '20 Jun, 2022'}
# 999  {'coming_soon': False, 'date': '23 Mar, 2023'}
#
#                                           support_info  \
# 0    {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                             {'url': '', 'email': ''}
# 2                             {'url': '', 'email': ''}
# 3                             {'url': '', 'email': ''}
# 4    {'url': 'https://help.steampowered.com', 'emai...
# ..                                                 ...
# 995  {'url': 'https://www.blobfish.dev/contact/', '...
# 996    {'url': '', 'email': 'support@hypecopilot.com'}
# 997     {'url': 'https://trebuchet.fun/', 'email': ''}
# 998     {'url': '', 'email': 'mrfatcat.dev@gmail.com'}
# 999  {'url': 'http://www.capcom.co.jp/support/conta...
#
#                                             background  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...
# 1    https://cdn.akamai.steamstatic.com/steam/apps/...
# 2    https://cdn.akamai.steamstatic.com/steam/apps/...
# 3    https://cdn.akamai.steamstatic.com/steam/apps/...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...
# ..                                                 ...
# 995  https://cdn.akamai.steamstatic.com/steam/apps/...
# 996  https://cdn.akamai.steamstatic.com/steam/apps/...
# 997  https://cdn.akamai.steamstatic.com/steam/apps/...
# 998  https://cdn.akamai.steamstatic.com/steam/apps/...
# 999  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                    content_descriptors
# 0    {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1    {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                           {'ids': [], 'notes': None}
# 3                           {'ids': [], 'notes': None}
# 4                           {'ids': [], 'notes': None}
# ..                                                 ...
# 995                         {'ids': [], 'notes': None}
# 996                         {'ids': [], 'notes': None}
# 997                         {'ids': [], 'notes': None}
# 998                         {'ids': [], 'notes': None}
# 999  {'ids': [2, 5], 'notes': 'This Game may contai...
#
# [1000 rows x 39 columns]

# %%
new_columns = ['name','detailed_description', 'short_description', 'header_image', 'categories', 'genres']
new_csv = game_csv[new_columns]

# %%
text_data = pd.read_csv(game_file, usecols=['name','detailed_description', 'short_description', 'categories', 'genres'])

# %%
text_data
# Out:
#                           name  \
# 0               Counter-Strike
# 1        Team Fortress Classic
# 2                Day of Defeat
# 3           Deathmatch Classic
# 4    Half-Life: Opposing Force
# ..                         ...
# 995                    Brotato
# 996       Escape the Backrooms
# 997                Broken Edge
# 998       Inside the Backrooms
# 999            Resident Evil 4
#
#                                   detailed_description  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  <h1>Previous games</h1><p><a href="https://sto...
# 996  Explore the seemingly infinite expanse of eeri...
# 997  <img src="https://cdn.akamai.steamstatic.com/s...
# 998  <img src="https://cdn.akamai.steamstatic.com/s...
# 999  <h1>Digital Deluxe Edition</h1><p><img src="ht...
#
#                                      short_description  \
# 0    Play the world's number 1 online action game. ...
# 1    One of the most popular online action games of...
# 2    Enlist in an intense brand of Axis vs. Allied ...
# 3    Enjoy fast-paced multiplayer gaming with Death...
# 4    Return to the Black Mesa Research Facility as ...
# ..                                                 ...
# 995  Brotato is a top-down arena shooter roguelite ...
# 996  Escape the Backrooms is a 1-4 player co-op hor...
# 997  Broken Edge is a VR multiplayer fantasy duelin...
# 998  Inside the Backrooms is a horror multiplayer g...
# 999  Survival is just the beginning. Six years have...
#
#                                             categories  \
# 0    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3    [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4    [{'id': 2, 'description': 'Single-player'}, {'...
# ..                                                 ...
# 995  [{'id': 2, 'description': 'Single-player'}, {'...
# 996  [{'id': 2, 'description': 'Single-player'}, {'...
# 997  [{'id': 2, 'description': 'Single-player'}, {'...
# 998  [{'id': 2, 'description': 'Single-player'}, {'...
# 999  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                 genres
# 0               [{'id': '1', 'description': 'Action'}]
# 1               [{'id': '1', 'description': 'Action'}]
# 2               [{'id': '1', 'description': 'Action'}]
# 3               [{'id': '1', 'description': 'Action'}]
# 4               [{'id': '1', 'description': 'Action'}]
# ..                                                 ...
# 995  [{'id': '1', 'description': 'Action'}, {'id': ...
# 996  [{'id': '23', 'description': 'Indie'}, {'id': ...
# 997             [{'id': '1', 'description': 'Action'}]
# 998  [{'id': '25', 'description': 'Adventure'}, {'i...
# 999  [{'id': '1', 'description': 'Action'}, {'id': ...
#
# [1000 rows x 5 columns]

# %%
import torchtext

# %%
pip install torchtext==0.6.0
# Out:
# Requirement already satisfied: torchtext==0.6.0 in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.27.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.0.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.16.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (0.1.99)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.6.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.6.0) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.6.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.6.0) (1.3.0)
# ^C

# %%
import torchtext.vocab as vocab
import torchtext.data as data

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)
# ERROR: Operation cancelled by user

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 187, in _run_module_as_main
#     mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
#   File "/usr/lib/python3.10/runpy.py", line 146, in _get_module_details
#     return _get_module_details(pkg_main_name, error)
#   File "/usr/lib/python3.10/runpy.py", line 110, in _get_module_details
#     __import__(pkg_name)
#   File "/usr/local/lib/python3.10/dist-packages/spacy/__init__.py", line 6, in <module>
#     from .errors import setup_default_warnings
#   File "/usr/local/lib/python3.10/dist-packages/spacy/errors.py", line 2, in <module>
#     from .compat import Literal
#   File "/usr/local/lib/python3.10/dist-packages/spacy/compat.py", line 3, in <module>
#     from thinc.util import copy_array
#   File "/usr/local/lib/python3.10/dist-packages/thinc/__init__.py", line 5, in <module>
#     from .config import registry
#   File "/usr/local/lib/python3.10/dist-packages/thinc/config.py", line 4, in <module>
#     from .types import Decorator
#   File "/usr/local/lib/python3.10/dist-packages/thinc/types.py", line 8, in <module>
#     from .compat import has_cupy, cupy
#   File "/usr/local/lib/python3.10/dist-packages/thinc/compat.py", line 30, in <module>
#     import torch.utils.dlpack
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1465, in <module>
#     from . import _meta_registrations
#   File "/usr/local/lib/python3.10/dist-packages/torch/_meta_registrations.py", line 7, in <module>
#     from torch._decomp import _add_op_to_registry, global_decomposition_table, meta_table
#   File "/usr/local/lib/python3.10/dist-packages/torch/_decomp/__init__.py", line 169, in <module>
#     import torch._decomp.decompositions
#   File "/usr/local/lib/python3.10/dist-packages/torch/_decomp/decompositions.py", line 10, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py", line 33, in <module>
#     from torch._subclasses.fake_tensor import FakeTensor, FakeTensorMode
#   File "/usr/local/lib/python3.10/dist-packages/torch/_subclasses/__init__.py", line 3, in <module>
#     from torch._subclasses.fake_tensor import (
#   File "/usr/local/lib/python3.10/dist-packages/torch/_subclasses/fake_tensor.py", line 13, in <module>
#     from torch._guards import Source
#   File "/usr/local/lib/python3.10/dist-packages/torch/_guards.py", line 14, in <module>
#     import sympy  # type: ignore[import]
#   File "/usr/local/lib/python3.10/dist-packages/sympy/__init__.py", line 196, in <module>
#     from .geometry import (Point, Point2D, Point3D, Line, Ray, Segment, Line2D,
#   File "/usr/local/lib/python3.10/dist-packages/sympy/geometry/__init__.py", line 13, in <module>
#     from sympy.geometry.point import Point, Point2D, Point3D
#   File "/usr/local/lib/python3.10/dist-packages/sympy/geometry/point.py", line 37, in <module>
#     from .entity import GeometryEntity
#   File "/usr/local/lib/python3.10/dist-packages/sympy/geometry/entity.py", line 571, in <module>
#     def intersection_sets(self, o): # noqa:F811
#   File "/usr/local/lib/python3.10/dist-packages/sympy/multipledispatch/core.py", line 70, in _
#     dispatcher.add(types, func, on_ambiguity=on_ambiguity)
#   File "/usr/local/lib/python3.10/dist-packages/sympy/multipledispatch/dispatcher.py", line 219, in add
#     self.reorder(on_ambiguity=on_ambiguity)
#   File "/usr/local/lib/python3.10/dist-packages/sympy/multipledispatch/dispatcher.py", line 224, in reorder
#     self.ordering = ordering(self.funcs)
#   File "/usr/local/lib/python3.10/dist-packages/sympy/multipledispatch/conflict.py", line 62, in ordering
#     edges = [(a, b) for a in signatures for b in signatures if edge(a, b)]
#   File "/usr/local/lib/python3.10/dist-packages/sympy/multipledispatch/conflict.py", line 62, in <listcomp>
#     edges = [(a, b) for a in signatures for b in signatures if edge(a, b)]
#   File "/usr/local/lib/python3.10/dist-packages/sympy/multipledispatch/conflict.py", line 48, in edge
#     if supercedes(a, b):
#   File "/usr/local/lib/python3.10/dist-packages/sympy/multipledispatch/conflict.py", line 9, in supercedes
#     return len(a) == len(b) and all(map(issubclass, a, b))
# KeyboardInterrupt
# ^C

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def tokenizer(text):
    return word_tokenize(text)

# %%
fields = [('detailed_description', data.Field(sequential=True, tokenize=tokenizer, lower=True)),
          ('short_description', data.Field(sequential=True, tokenize=tokenizer, lower=True)),
          ('categories', data.Field(sequential=True, tokenize=tokenizer, lower=True)),
          ('genres', data.Field(sequential=True, tokenize=tokenizer, lower=True)),]

train_data = data.TabularDataset(path=game_file, format='csv', fields=fields, skip_header=True)

# %%
# Define the path to the extracted GloVe embeddings file
glove_path = '/content/GloVe-1.2.zip'

# Define the TEXT field
TEXT = data.Field(sequential=True, tokenize=tokenizer, lower=True)

# Load the GloVe embeddings into the vocabulary
vectors = vocab.GloVe(name='6B', dim=100, cache='/content/glove/')  # Specify the dimensions (dim) as 100

# Build the vocabulary with the GloVe embeddings
TEXT.build_vocab(train_data, vectors=vectors)

# %%
import torch.nn.utils.rnn as rnn_utils

# %%
# Text preprocessing and embedding function
def text_to_tensor(detailed_description, short_description):
    detailed_tokens = TEXT.preprocess(detailed_description)
    short_tokens = TEXT.preprocess(short_description)

    # Ensure both sequences have the same length by padding the shorter one
    max_length = max(len(detailed_tokens), len(short_tokens))
    detailed_padded = [TEXT.vocab.stoi[token] for token in detailed_tokens] + [TEXT.vocab.stoi[TEXT.pad_token]] * (max_length - len(detailed_tokens))
    short_padded = [TEXT.vocab.stoi[token] for token in short_tokens] + [TEXT.vocab.stoi[TEXT.pad_token]] * (max_length - len(short_tokens))

    detailed_embed = torch.tensor(detailed_padded, dtype=torch.long).unsqueeze(0)  # Add batch dimension and set dtype
    short_embed = torch.tensor(short_padded, dtype=torch.long).unsqueeze(0)  # Add batch dimension and set dtype

    return torch.cat((detailed_embed, short_embed), dim=1)  # Concatenate along the second dimension

# %%
# Example usage:
detailed_example = "This is a detailed description of a game."
short_example = "Short description."
combined_example = text_to_tensor(detailed_example, short_example)

# %% [markdown]
# ### Actual text processing on games

# %%
EMBEDDING_DIM = vectors.vectors.shape[1]

# %%
embeddings_list = []
max_length = 0  # Initialize max_length to zero

# Step 2: Process each row and obtain text embeddings
for index, row in text_data.iterrows():
    detailed_description = row['detailed_description']
    short_description = row['short_description']

    # Handle missing values by filling them with empty strings ('')
    detailed_description = str(detailed_description) if not pd.isnull(detailed_description) else ''
    short_description = str(short_description) if not pd.isnull(short_description) else ''

    embeddings = text_to_tensor(detailed_description, short_description)
    embeddings_list.append(embeddings)

    # Update the maximum length
    max_length = max(max_length, embeddings.shape[1])

# %%
from torch.nn.utils.rnn import pad_sequence

# %%
# Calculate the correct max_length based on the actual length of the longest sequence
max_length = max(embeddings_list[i].shape[1] for i in range(len(embeddings_list)))

# Pad all sequences to match the maximum length
padded_embeddings_list = [torch.nn.functional.pad(tensor, (0, max_length - tensor.shape[1], 0, 0), value=0) for tensor in embeddings_list]

# Stack all text embeddings into a single tensor
combined_text_embeddings = torch.stack(padded_embeddings_list, dim=0)

# %%
from sklearn.cluster import KMeans

# Flatten the embeddings to 2D for clustering
num_samples, max_length, embedding_dim = combined_text_embeddings.size()
combined_text_embeddings = combined_text_embeddings.view(num_samples, -1)

# Number of clusters (you can adjust this based on your requirements)
num_clusters = 10

# Create the KMeans clustering model
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)

# Fit the model to the combined text embeddings
kmeans_model.fit(combined_text_embeddings)

# Get the cluster assignments for each game
cluster_assignments = kmeans_model.labels_

# Add the cluster assignments back to the original dataframe
text_data['cluster'] = cluster_assignments
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
from sklearn.manifold import TSNE

# %%
# Apply t-SNE for dimensionality reduction
# tsne = TSNE(n_components=2, random_state=42)
tsne = TSNE(n_components=2)

tsne_result = tsne.fit_transform(combined_text_embeddings)

# %%
# Add the t-SNE embeddings to the DataFrame
text_data['x'] = tsne_result[:, 0]
text_data['y'] = tsne_result[:, 1]

# %%
import matplotlib.pyplot as plt

# %%
text_data['combined_text'] = text_data['detailed_description'] + ' ' + text_data['short_description'] + ' ' + text_data['categories'] + text_data['genres']

# Handle NaN values in the combined_text column
text_data['combined_text'] = text_data['combined_text'].fillna('')

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.2)

# %%
import plotly.graph_objects as go

# Create a scatter plot to visualize the clusters
colors = ['blue', 'green', 'red', 'purple', 'orange', 'yellow', 'cyan', 'magenta', 'lime', 'pink', 'teal', 'brown']

scatter_trace = go.Scatter(
    x=text_data['x'],
    y=text_data['y'],
    mode='markers',
    marker=dict(
        color=[colors[i] for i in text_data['cluster']],
        size=8,
        opacity=0.5,
        line=dict(width=0)
    ),
    hovertext=text_data['name'],  # Set the game names as tooltips
    hoverinfo='text'
)

layout = go.Layout(
    title='Cluster Visualization',
    xaxis=dict(title='X'),
    yaxis=dict(title='Y')
)

fig = go.Figure(data=[scatter_trace], layout=layout)
fig.update_layout(hovermode='closest')  # Show the closest data point's name on hover
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d06341cf-e686-4861-b93b-dbcd7af9b14a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d06341cf-e686-4861-b93b-dbcd7af9b14a")) {                    Plotly.newPlot(                        "d06341cf-e686-4861-b93b-dbcd7af9b14a",                        [{"hoverinfo":"text","hovertext":["Counter-Strike","Team Fortress Classic","Day of Defeat","Deathmatch Classic","Half-Life: Opposing Force","Ricochet","Half-Life","Counter-Strike: Condition Zero","Half-Life: Blue Shift","Half-Life 2","Counter-Strike: Source","Half-Life: Source","Day of Defeat: Source","Half-Life 2: Deathmatch","Half-Life 2: Lost Coast","Half-Life Deathmatch: Source","Half-Life 2: Episode One","Portal","Half-Life 2: Episode Two","Team Fortress 2","Left 4 Dead","Left 4 Dead 2","Dota 2","Portal 2","Alien Swarm","Counter-Strike: Global Offensive","Killing Floor","Source Filmmaker","Dark Messiah of Might & Magic","DOOM (1993)","Quake","The Ship: Murder Party","Call of Duty\u00ae 2","Plants vs. Zombies GOTY Edition","Psychonauts","Sid Meier's Civilization\u00ae IV","Sid Meier's Civilization\u00ae III Complete","Garry's Mod","S.T.A.L.K.E.R.: Shadow of Chernobyl","Company of Heroes - Legacy Edition","Warhammer\u00ae 40,000: Dawn of War\u00ae - Game of the Year Edition","Warhammer\u00ae 40,000: Dawn of War\u00ae - Dark Crusade","Total War: MEDIEVAL II \u2013 Definitive Edition","Rome: Total War\u2122 - Collection","Natural Selection 2","STAR WARS\u2122 Republic Commando\u2122","STAR WARS\u2122 Jedi Knight - Jedi Academy\u2122","Star Wars: Battlefront 2 (Classic, 2005)","Hitman 2: Silent Assassin","Hitman: Blood Money","Just Cause","Hitman: Codename 47","Deus Ex: Game of the Year Edition","Deus Ex: Invisible War","BioShock\u2122","X-COM: UFO Defense","Call of Duty\u00ae 4: Modern Warfare\u00ae (2007)","Just Cause 2","Sam & Max 104: Abe Lincoln Must Die!","EVE Online","BioShock\u00ae 2","BioShock Infinite","Sid Meier's Civilization\u00ae V","Borderlands Game of the Year","Company of Heroes: Opposing Fronts","Supreme Commander: Forged Alliance","Warhammer\u00ae 40,000: Dawn of War\u00ae - Soulstorm","Saints Row 2","Champions Online","Star Trek Online","Call of Duty: World at War","Call of Duty\u00ae: Modern Warfare\u00ae 2 (2009)","Total War: EMPIRE \u2013 Definitive Edition","Aliens vs. Predator\u2122","TrackMania Nations Forever","Grand Theft Auto III","Grand Theft Auto: Vice City","Grand Theft Auto: San Andreas","Bully: Scholarship Edition","Grand Theft Auto IV: The Complete Edition","Grand Theft Auto: Episodes from Liberty City","Overlord II","AudioSurf","Far Cry\u00ae","Assassin's Creed\u2122: Director's Cut Edition","Warhammer 40,000: Dawn of War II","Oddworld: Abe's Oddysee\u00ae","Tribes: Ascend","Crysis","Crysis Warhead\u00ae","SPORE\u2122","Mirror's Edge\u2122","Mass Effect (2007)","Dead Space (2008)","Command & Conquer: Red Alert 3","Alice: Madness Returns","Far Cry\u00ae 2","Red Faction Guerrilla Steam Edition","S.T.A.L.K.E.R.: Clear Sky","Warhammer\u00ae 40,000: Dawn of War\u00ae II Chaos Rising","The Witcher: Enhanced Edition Director's Cut","The Witcher 2: Assassins of Kings Enhanced Edition","F.E.A.R. 3","F.E.A.R.","F.E.A.R.","Resident Evil 5","World of Goo","The Elder Scrolls III: Morrowind\u00ae Game of the Year Edition","The Elder Scrolls IV: Oblivion\u00ae Game of the Year Edition","BRINK","Fallout 3: Game of the Year Edition","Fallout: New Vegas","DC Universe\u2122 Online","PAYDAY\u2122 The Heist","Burnout Paradise: The Ultimate Box","Battlefield: Bad Company\u2122 2","Mass Effect 2 (2010 Edition)","Braid","STAR WARS\u2122 Knights of the Old Republic\u2122","STAR WARS\u2122 - The Force Unleashed\u2122 Ultimate Sith Edition","STAR WARS\u2122 Empire at War - Gold Pac ...
